# %% [markdown]
# # <center>Heart Rate Variability (HRV) analysis using time domain, frequency domain and non-linear methods</center>

# %% [markdown]
# <section data-markdown>
#     <img src="https://d1a0efioav7lro.cloudfront.net/wp-content/uploads/2020/02/07020753/Heart-Rate-Variability1.png"/>
# </section>

# %% [markdown]
# ## We wil use [Neurokit](https://pypi.org/project/neurokit2/) and [PyHRV](https://pypi.org/project/pyhrv/) to analyze data from ECG and PPG

# %%
# !pip install PyWavelets
# Out:
# Collecting PyWavelets
#   Downloading pywavelets-1.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 11.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy<3,>=1.23 in ./.venv/lib/python3.11/site-packages (from PyWavelets) (2.3.1)
# Installing collected packages: PyWavelets
# Successfully installed PyWavelets-1.8.0

# %%
import neurokit2 as nk
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.signal import find_peaks
from scipy import signal
from scipy.integrate import trapezoid
from scipy.interpolate import interp1d
import seaborn as sns
from matplotlib.patches import Ellipse

ppg_simulated=nk.ppg_simulate(duration=300, sampling_rate=500, heart_rate=60)
plt.plot(ppg_simulated)
plt.show()

# %% [markdown]
# ## Time Domain analysis

# %%
def timedomain(rr):
    results = {}

    hr = 60000/rr
    
    results['Mean RR (ms)'] = np.mean(rr)
    results['STD RR/SDNN (ms)'] = np.std(rr)
    results['Mean HR (Kubios\' style) (beats/min)'] = 60000/np.mean(rr)
    results['Mean HR (beats/min)'] = np.mean(hr)
    results['STD HR (beats/min)'] = np.std(hr)
    results['Min HR (beats/min)'] = np.min(hr)
    results['Max HR (beats/min)'] = np.max(hr)
    results['RMSSD (ms)'] = np.sqrt(np.mean(np.square(np.diff(rr))))
    results['NNxx'] = np.sum(np.abs(np.diff(rr)) > 50)*1
    results['pNNxx (%)'] = 100 * np.sum((np.abs(np.diff(rr)) > 50)*1) / len(rr)
    return results

# %% [markdown]
# ## Frequency Domain analysis

# %%
def frequency_domain(rri, fs=4):
    # Estimate the spectral density using Welch's method
    fxx, pxx = signal.welch(x=rr_interpolated, fs=fs)
    
    '''
    Segement found frequencies in the bands 
     - Very Low Frequency (VLF): 0-0.04Hz 
     - Low Frequency (LF): 0.04-0.15Hz 
     - High Frequency (HF): 0.15-0.4Hz
    '''
    cond_vlf = (fxx >= 0) & (fxx < 0.04)
    cond_lf = (fxx >= 0.04) & (fxx < 0.15)
    cond_hf = (fxx >= 0.15) & (fxx < 0.4)
    
    # calculate power in each band by integrating the spectral density 
    vlf = trapezoid(pxx[cond_vlf], fxx[cond_vlf])
    lf = trapezoid(pxx[cond_lf], fxx[cond_lf])
    hf = trapezoid(pxx[cond_hf], fxx[cond_hf])
    
    # sum these up to get total power
    total_power = vlf + lf + hf

    # find which frequency has the most power in each band
    peak_vlf = fxx[cond_vlf][np.argmax(pxx[cond_vlf])]
    peak_lf = fxx[cond_lf][np.argmax(pxx[cond_lf])]
    peak_hf = fxx[cond_hf][np.argmax(pxx[cond_hf])]

    # fraction of lf and hf
    lf_nu = 100 * lf / (lf + hf)
    hf_nu = 100 * hf / (lf + hf)
    
    results = {}
    results['Power VLF (ms2)'] = vlf
    results['Power LF (ms2)'] = lf
    results['Power HF (ms2)'] = hf   
    results['Power Total (ms2)'] = total_power

    results['LF/HF'] = (lf/hf)
    results['Peak VLF (Hz)'] = peak_vlf
    results['Peak LF (Hz)'] = peak_lf
    results['Peak HF (Hz)'] = peak_hf

    results['Fraction LF (nu)'] = lf_nu
    results['Fraction HF (nu)'] = hf_nu
    return results, fxx, pxx

# %% [markdown]
# ## Poincare analysis (non-linear)

# %%
def plot_poincare(rr):
    rr_n = rr[:-1]
    rr_n1 = rr[1:]

    sd1 = np.sqrt(0.5) * np.std(rr_n1 - rr_n)
    sd2 = np.sqrt(0.5) * np.std(rr_n1 + rr_n)

    m = np.mean(rr)
    min_rr = np.min(rr)
    max_rr = np.max(rr)
    
    plt.figure(figsize=(10, 10))
    plt.title("Poincare plot")

    sns.scatterplot(x=rr_n, y=rr_n1, color="#51A6D8")

    plt.xlabel(r'$RR_n (ms)$')
    plt.ylabel(r'$RR_{n+1} (ms)$')

    e1 = Ellipse((m, m), 2*sd1, 2*sd2, angle=-45, linewidth=1.2, fill=False, color="k")
    plt.gca().add_patch(e1)

    plt.arrow(m, m, (max_rr-min_rr)*0.4, (max_rr-min_rr)*0.4, color="k", linewidth=0.8, head_width=5, head_length=5)
    plt.arrow(m, m, (min_rr-max_rr)*0.4, (max_rr-min_rr)*0.4, color="k", linewidth=0.8, head_width=5, head_length=5)

    plt.arrow(m, m, sd2 * np.sqrt(0.5), sd2 * np.sqrt(0.5), color="green", linewidth=5)
    plt.arrow(m, m, -sd1 * np.sqrt(0.5), sd1 * np.sqrt(0.5), color="red", linewidth=5)

    plt.text(max_rr, max_rr, "SD2", fontsize=20, color="green")
    plt.text(m-(max_rr-min_rr)*0.4-20, max_rr, "SD1", fontsize=20, color="red")
    
    return sd1, sd2

# %% [markdown]
# # From NeuroKit 2 we import a 5min PPG and ECG-recording ([https://github.com/neuropsychology/NeuroKit/blob/master/data/bio_resting_5min_100hz.csv](https://github.com/neuropsychology/NeuroKit/blob/master/data/bio_resting_5min_100hz.csv))

# %%
ppg_and_ecg=nk.data(dataset="bio_resting_5min_100hz")

# %% [markdown]
# ### Plot the first 5 seconds of the data

# %%
plt.plot(ppg_and_ecg['PPG'][0:500])
plt.plot(ppg_and_ecg['ECG'][0:500])
plt.title("PPG and ECG", color = "black")
plt.tick_params(axis="both", colors = "black")

# %%
diff_sig_2=np.diff(ppg_and_ecg['PPG'])

# %%
# HR will probably not go below 30 bpm : distance=500*(30/60))
# prominence found experimentally
peaks_2, _ = find_peaks(diff_sig_2, distance=100*(30/60), prominence=0.01)

# %% [markdown]
# ### First 10 seconds of PPG measurements

# %%
plt.figure(figsize=(20,8))
plt.subplot(2,1,1)
plt.plot(ppg_and_ecg['PPG'])
plt.scatter(peaks_2, ppg_and_ecg['PPG'][peaks_2], color="red")
plt.gca().set_xlim(0, 1000)
plt.subplot(2,1,2)
plt.plot(diff_sig_2)
plt.scatter(peaks_2, diff_sig_2[peaks_2], color="red")
plt.gca().set_xlim(0, 1000)
plt.show()

# %%
rr_2 = np.diff(peaks_2)
corr_rr_2 = rr_2*10

# %%
timedomain(corr_rr_2)
# Out:
# {'Mean RR (ms)': np.float64(694.6171693735499),
#  'STD RR/SDNN (ms)': np.float64(51.03821944801512),
#  "Mean HR (Kubios' style) (beats/min)": np.float64(86.3785155989044),
#  'Mean HR (beats/min)': np.float64(86.84239408606393),
#  'STD HR (beats/min)': np.float64(6.354812992315708),
#  'Min HR (beats/min)': np.float64(68.18181818181819),
#  'Max HR (beats/min)': np.float64(109.0909090909091),
#  'RMSSD (ms)': np.float64(41.07848415490908),
#  'NNxx': np.int64(67),
#  'pNNxx (%)': np.float64(15.54524361948956)}

# %% [markdown]
# ## To be able to do frequency analysis we have to interpolate the RR-interval curve (PPG)

# %%
x_2 = np.cumsum(rr_2)/ 100.0
f_2 = interp1d(x_2, rr_2, kind='cubic',fill_value="extrapolate")

# sample rate for interpolation
fs = 4.0
steps = 1 / fs

# now we can sample from interpolation function
xx_2 = np.arange(1, np.max(x_2), steps)

rr_interpolated = f_2(xx_2)

plt.figure(figsize=(20, 15))

plt.subplot(211)
plt.title("RR intervals")
plt.plot(x_2, rr_2, color="k", markerfacecolor="#A651D8", markeredgewidth=0, marker="o", markersize=8)
plt.xlabel("Time (s)")
plt.ylabel("RR-interval (ms)")
plt.title("Interpolated")
plt.gca().set_xlim(0, 300)

plt.subplot(212)
plt.title("RR-Intervals (cubic interpolation)")
plt.plot(xx_2, rr_interpolated, color="k", markerfacecolor="#51A6D8", markeredgewidth=0, marker="o", markersize=8)
plt.gca().set_xlim(0, 300)
plt.xlabel("Time (s)")
plt.ylabel("RR-interval (ms)")
plt.show()

# %%
print("Frequency domain metrics:")
results_2, fxx_2, pxx_2 = frequency_domain(rr_interpolated)

for k, v in results_2.items():
    print("- %s: %.2f" % (k, v))
# Out:
# Frequency domain metrics:
# - Power VLF (ms2): 3.64
# - Power LF (ms2): 7.07
# - Power HF (ms2): 7.81
# - Power Total (ms2): 18.53
# - LF/HF: 0.91
# - Peak VLF (Hz): 0.02
# - Peak LF (Hz): 0.09
# - Peak HF (Hz): 0.28
# - Fraction LF (nu): 47.51
# - Fraction HF (nu): 52.49

# %% [markdown]
# ## Welch periodogram (PPG)

# %%
plt.figure(figsize=(20, 7))
plt.plot(fxx_2, pxx_2, color="k", linewidth=0.3)
plt.title("FFT Spectrum (Welch's periodogram)")

# create interpolation function for plotting frequency bands
psd_f = interp1d(fxx_2, pxx_2)

# setup frequency bands for plotting
x_vlf = np.linspace(0, 0.04, 100)
x_lf = np.linspace(0.04, 0.15, 100)
x_hf = np.linspace(0.15, 0.4, 100)

plt.gca().fill_between(x_vlf, psd_f(x_vlf), alpha=0.2, color="#A651D8", label="VLF")
plt.gca().fill_between(x_lf, psd_f(x_lf), alpha=0.2, color="#51A6D8", label="LF")
plt.gca().fill_between(x_hf, psd_f(x_hf), alpha=0.2, color="#D8A651", label="HF")

plt.gca().set_xlim(0, 0.5)
plt.gca().set_ylim(0)
plt.xlabel("Frequency (Hz)")
plt.ylabel("Density")
plt.legend()
plt.show()

# %% [markdown]
# ## Poincare diagram (PPG)

# %%
import seaborn as sns
from matplotlib.patches import Ellipse
sd1_2, sd2_2 = plot_poincare(rr_2)
print("SD1: %.3f ms" % sd1_2)
print("SD2: %.3f ms" % sd2_2)
# Out:
# SD1: 2.905 ms
# SD2: 6.592 ms

# %% [markdown]
# # Analysis ECG signal

# %%
ecg_signals, info  = nk.ecg_process(ppg_and_ecg["ECG"], sampling_rate=100)

# %% [markdown]
# ### Plot first 10 seconds of ECG signal

# %%
plt.plot(ppg_and_ecg["ECG"])
plt.scatter(info['ECG_R_Peaks'], ppg_and_ecg["ECG"][info['ECG_R_Peaks']], color="red")
plt.gca().set_xlim(0, 1000)
plt.show()

# %%
rr_ecg = np.diff(info['ECG_R_Peaks'])
corr_rr_ecg = rr_ecg*10

# %% [markdown]
# ## Timedomain analysis of ECG

# %%
timedomain(corr_rr_ecg)
# Out:
# {'Mean RR (ms)': np.float64(694.7563805104409),
#  'STD RR/SDNN (ms)': np.float64(48.97912382493174),
#  "Mean HR (Kubios' style) (beats/min)": np.float64(86.36120758749665),
#  'Mean HR (beats/min)': np.float64(86.7938136813782),
#  'STD HR (beats/min)': np.float64(6.183591575643686),
#  'Min HR (beats/min)': np.float64(69.76744186046511),
#  'Max HR (beats/min)': np.float64(115.38461538461539),
#  'RMSSD (ms)': np.float64(38.83776632381496),
#  'NNxx': np.int64(57),
#  'pNNxx (%)': np.float64(13.22505800464037)}

# %% [markdown]
# ## Interpolated ECG signal

# %%
x_ecg = np.cumsum(rr_ecg)/ 100.0
f_ecg = interp1d(x_ecg, rr_ecg, kind='cubic',fill_value="extrapolate")

# sample rate for interpolation
fs = 4.0
steps = 1 / fs

# now we can sample from interpolation function
xx_ecg = np.arange(1, np.max(x_ecg), steps)
xx_ecg.shape

rr_interpolated_ecg = f_ecg(xx_ecg)

plt.figure(figsize=(20, 15))

plt.subplot(211)
plt.title("RR intervals")
plt.plot(x_ecg, rr_ecg, color="k", markerfacecolor="#A651D8", markeredgewidth=0, marker="o", markersize=8)
plt.xlabel("Time (s)")
plt.ylabel("RR-interval (ms)")
plt.title("Interpolated")
plt.gca().set_xlim(0, 300)

plt.subplot(212)
plt.title("RR-Intervals (cubic interpolation)")
plt.plot(xx_ecg, rr_interpolated_ecg, color="k", markerfacecolor="#51A6D8", markeredgewidth=0, marker="o", markersize=8)
plt.gca().set_xlim(0, 300)
plt.xlabel("Time (s)")
plt.ylabel("RR-interval (ms)")
plt.show()

# %% [markdown]
# ## Frequenzy domain analysis off ECG signal

# %%
print("Frequency domain metrics:")
results_ecg, fxx_ecg, pxx_ecg = frequency_domain(rr_interpolated_ecg)

for k_e, v_e in results_ecg.items():
    print("- %s: %.2f" % (k_e, v_e))
# Out:
# Frequency domain metrics:
# - Power VLF (ms2): 3.64
# - Power LF (ms2): 7.07
# - Power HF (ms2): 7.81
# - Power Total (ms2): 18.53
# - LF/HF: 0.91
# - Peak VLF (Hz): 0.02
# - Peak LF (Hz): 0.09
# - Peak HF (Hz): 0.28
# - Fraction LF (nu): 47.51
# - Fraction HF (nu): 52.49

# %% [markdown]
# # Welch diagram for ECG signal

# %%
plt.figure(figsize=(20, 7))
plt.plot(fxx_ecg, pxx_ecg, color="k", linewidth=0.3)
plt.title("FFT Spectrum (Welch's periodogram)")

# create interpolation function for plotting frequency bands
psd_f = interp1d(fxx_ecg, pxx_ecg)

# setup frequency bands for plotting
x_vlf = np.linspace(0, 0.04, 100)
x_lf = np.linspace(0.04, 0.15, 100)
x_hf = np.linspace(0.15, 0.4, 100)

plt.gca().fill_between(x_vlf, psd_f(x_vlf), alpha=0.2, color="#A651D8", label="VLF")
plt.gca().fill_between(x_lf, psd_f(x_lf), alpha=0.2, color="#51A6D8", label="LF")
plt.gca().fill_between(x_hf, psd_f(x_hf), alpha=0.2, color="#D8A651", label="HF")

plt.gca().set_xlim(0, 0.5)
plt.gca().set_ylim(0)
plt.xlabel("Frequency (Hz)")
plt.ylabel("Density")
plt.legend()
plt.show()

# %% [markdown]
# ## Poincare analysis of ECG signal

# %%
sd1_ecg, sd2_ecg = plot_poincare(rr_ecg)
print("SD1: %.3f ms" % sd1_ecg)
print("SD2: %.3f ms" % sd2_ecg)
# Out:
# SD1: 2.746 ms
# SD2: 6.341 ms

# %% [markdown]
# ## We wil use now use [PyHRV](https://pypi.org/project/pyhrv/) to analyze the data

# %%
# !pip install hrv-analysis
# Out:
# Collecting hrv-analysis
#   Downloading hrv_analysis-1.0.5-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.6/40.6 kB 1.1 MB/s eta 0:00:00
# Collecting astropy>=3.2.2
#   Downloading astropy-7.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 7.9 MB/s eta 0:00:0000:010:01
# Requirement already satisfied: matplotlib>=2.2.2 in ./.venv/lib/python3.11/site-packages (from hrv-analysis) (3.10.3)
# Collecting nolds>=0.4.1
#   Downloading nolds-0.6.2-py2.py3-none-any.whl (225 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.7/225.7 kB 17.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.15.1 in ./.venv/lib/python3.11/site-packages (from hrv-analysis) (2.3.1)
# Requirement already satisfied: pandas>=1.2.0 in ./.venv/lib/python3.11/site-packages (from hrv-analysis) (2.3.0)
# Requirement already satisfied: scipy>=1.1.0 in ./.venv/lib/python3.11/site-packages (from hrv-analysis) (1.16.0)
# Collecting pyerfa>=2.0.1.1
#   Downloading pyerfa-2.0.1.5-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (738 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 738.7/738.7 kB 17.5 MB/s eta 0:00:00a 0:00:01
# Collecting astropy-iers-data>=0.2025.4.28.0.37.27
#   Downloading astropy_iers_data-0.2025.6.30.0.39.40-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 17.1 MB/s eta 0:00:00a 0:00:01
# Collecting PyYAML>=6.0.0
#   Downloading PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (762 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.0/763.0 kB 17.4 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: packaging>=22.0.0 in ./.venv/lib/python3.11/site-packages (from astropy>=3.2.2->hrv-analysis) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.11/site-packages (from matplotlib>=2.2.2->hrv-analysis) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.11/site-packages (from matplotlib>=2.2.2->hrv-analysis) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.11/site-packages (from matplotlib>=2.2.2->hrv-analysis) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.11/site-packages (from matplotlib>=2.2.2->hrv-analysis) (1.4.8)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.11/site-packages (from matplotlib>=2.2.2->hrv-analysis) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.11/site-packages (from matplotlib>=2.2.2->hrv-analysis) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.11/site-packages (from matplotlib>=2.2.2->hrv-analysis) (2.9.0.post0)
# Collecting future
#   Downloading future-1.0.0-py3-none-any.whl (491 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.3/491.3 kB 20.1 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in ./.venv/lib/python3.11/site-packages (from nolds>=0.4.1->hrv-analysis) (66.1.1)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.11/site-packages (from pandas>=1.2.0->hrv-analysis) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.11/site-packages (from pandas>=1.2.0->hrv-analysis) (2025.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=2.2.2->hrv-analysis) (1.17.0)
# Installing collected packages: PyYAML, pyerfa, future, astropy-iers-data, nolds, astropy, hrv-analysis
# Successfully installed PyYAML-6.0.2 astropy-7.1.0 astropy-iers-data-0.2025.6.30.0.39.40 future-1.0.0 hrv-analysis-1.0.5 nolds-0.6.2 pyerfa-2.0.1.5

# %%
# !pip install pyhrv
# Out:
# Collecting pyhrv
#   Downloading pyhrv-0.4.1-py3-none-any.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 11.8 MB/s eta 0:00:0000:010:01
# Collecting biosppy
#   Downloading biosppy-2.2.3-py2.py3-none-any.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.0/158.0 kB 11.9 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.11/site-packages (from pyhrv) (3.10.3)
# Requirement already satisfied: numpy in ./.venv/lib/python3.11/site-packages (from pyhrv) (2.3.1)
# Requirement already satisfied: scipy in ./.venv/lib/python3.11/site-packages (from pyhrv) (1.16.0)
# Requirement already satisfied: nolds in ./.venv/lib/python3.11/site-packages (from pyhrv) (0.6.2)
# Collecting spectrum
#   Downloading spectrum-0.9.0.tar.gz (231 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.5/231.5 kB 32.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting bidict
#   Downloading bidict-0.23.1-py3-none-any.whl (32 kB)
# Collecting h5py
#   Downloading h5py-3.14.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 13.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.11/site-packages (from biosppy->pyhrv) (1.7.0)
# Collecting shortuuid
#   Downloading shortuuid-1.0.13-py3-none-any.whl (10 kB)
# Requirement already satisfied: six in ./.venv/lib/python3.11/site-packages (from biosppy->pyhrv) (1.17.0)
# Requirement already satisfied: joblib in ./.venv/lib/python3.11/site-packages (from biosppy->pyhrv) (1.5.1)
# Collecting opencv-python
#   Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (63.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 MB 9.2 MB/s eta 0:00:00:00:0100:01
# Requirement already satisfied: pywavelets in ./.venv/lib/python3.11/site-packages (from biosppy->pyhrv) (1.8.0)
# Collecting mock
#   Downloading mock-5.2.0-py3-none-any.whl (31 kB)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.11/site-packages (from matplotlib->pyhrv) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.11/site-packages (from matplotlib->pyhrv) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.11/site-packages (from matplotlib->pyhrv) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.11/site-packages (from matplotlib->pyhrv) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.11/site-packages (from matplotlib->pyhrv) (25.0)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.11/site-packages (from matplotlib->pyhrv) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.11/site-packages (from matplotlib->pyhrv) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.11/site-packages (from matplotlib->pyhrv) (2.9.0.post0)
# Requirement already satisfied: future in ./.venv/lib/python3.11/site-packages (from nolds->pyhrv) (1.0.0)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.11/site-packages (from nolds->pyhrv) (66.1.1)
# Collecting easydev
#   Downloading easydev-0.13.3-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 15.2 MB/s eta 0:00:00
# Collecting colorama<0.5.0,>=0.4.6
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting colorlog<7.0.0,>=6.8.2
#   Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Collecting line-profiler<5.0.0,>=4.1.2
#   Downloading line_profiler-4.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (750 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.2/750.2 kB 15.2 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: pexpect<5.0.0,>=4.9.0 in ./.venv/lib/python3.11/site-packages (from easydev->spectrum->pyhrv) (4.9.0)
# Requirement already satisfied: platformdirs<5.0.0,>=4.2.0 in ./.venv/lib/python3.11/site-packages (from easydev->spectrum->pyhrv) (4.3.8)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.venv/lib/python3.11/site-packages (from scikit-learn->biosppy->pyhrv) (3.6.0)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.11/site-packages (from pexpect<5.0.0,>=4.9.0->easydev->spectrum->pyhrv) (0.7.0)
# Installing collected packages: shortuuid, opencv-python, mock, line-profiler, h5py, colorlog, colorama, bidict, easydev, spectrum, biosppy, pyhrv
#   DEPRECATION: spectrum is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   Running setup.py install for spectrum ... done
# Successfully installed bidict-0.23.1 biosppy-2.2.3 colorama-0.4.6 colorlog-6.9.0 easydev-0.13.3 h5py-3.14.0 line-profiler-4.2.0 mock-5.2.0 opencv-python-4.11.0.86 pyhrv-0.4.1 shortuuid-1.0.13 spectrum-0.9.0

# %%
from hrvanalysis import remove_outliers, remove_ectopic_beats, interpolate_nan_values

# %%
rr_intervals_list = info['ECG_R_Peaks']

# %%
# !pip install peakutils
# Out:
# Collecting peakutils
#   Downloading PeakUtils-1.3.5-py3-none-any.whl (7.7 kB)
# Requirement already satisfied: numpy in ./.venv/lib/python3.11/site-packages (from peakutils) (2.3.1)
# Requirement already satisfied: scipy in ./.venv/lib/python3.11/site-packages (from peakutils) (1.16.0)
# Installing collected packages: peakutils
# Successfully installed peakutils-1.3.5

# %%
import pyhrv.tools as tools

# %% [markdown]
# ## Welch diagram - PPG signal

# %%
import pyhrv.frequency_domain as fd
nni = tools.nn_intervals(rr_intervals_list)
result = fd.welch_psd(nni=nni)
# Access peak frequencies using the key 'fft_peak'
print(result['fft_peak'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 3
#       1 import pyhrv.frequency_domain as fd
#       2 nni = tools.nn_intervals(rr_intervals_list)
# ----> 3 result = fd.welch_psd(nni=nni)
#       4 # Access peak frequencies using the key 'fft_peak'
#       5 print(result['fft_peak'])
#
# File ~/workspace/hrv-analyze/.venv/lib/python3.11/site-packages/pyhrv/frequency_domain.py:159, in welch_psd(nni, rpeaks, fbands, nfft, detrend, window, show, show_param, legend, figsize, mode)
#     156 nn = pyhrv.utils.check_input(nni, rpeaks)
#     158 # Verify or set default frequency bands
# --> 159 fbands = _check_freq_bands(fbands)
#     161 # Resampling (with 4Hz) and interpolate
#     162 # Because RRi are unevenly spaced we must interpolate it for accurate PSD estimation.
#     163 fs = 4
#
# File ~/workspace/hrv-analyze/.venv/lib/python3.11/site-packages/pyhrv/frequency_domain.py:739, in _check_freq_bands(freq_bands)
#     736 	args = args_
#     737 	names = names_
# --> 739 return biosppy.utils.ReturnTuple(args, names)
#
# AttributeError: module 'biosppy' has no attribute 'utils'

# %% [markdown]
# ## Welch diagram - ECG signal

# %%
nni_2 = tools.nn_intervals(peaks_2)
result = fd.welch_psd(nni=nni_2)
# Access peak frequencies using the key 'fft_peak'
print(result['fft_peak'])
# Out:
# (0.0009765625, 0.083984375, 0.3828125)

# %% [markdown]
# # Non-linear analysis using PyHRV
# ### Poincare analysis PPG

# %%
import pyhrv.nonlinear as nl
result = nl.poincare(nni)
print(result['sd1'])
# Out:
# 3.0281338106725104

# %% [markdown]
# ### Sample Entropy PPG

# %%
result = nl.sample_entropy(nni)
print(result['sampen'])
# Out:
# 1.2492838973762872

# %% [markdown]
# ### Poincare analysis ECG

# %%
result = nl.poincare(nni_2)
print(result['sd1'])
# Out:
# 2.904657679624767

# %%
result = nl.sample_entropy(nni_2)
print(result['sampen'])
# Out:
# 1.388903285114691

# %% [markdown]
# - Makowski, D., Pham, T., Lau, Z. J., Brammer, J. C., Lesspinasse, F., Pham, H.,
#   Schölzel, C., & S H Chen, A. (2020). NeuroKit2: A Python Toolbox for Neurophysiological
#   Signal Processing. Retrieved May 07, 2020, from https://github.com/neuropsychology/NeuroKit
# - https://www.kaggle.com/stetelepta/exploring-heart-rate-variability-using-python
